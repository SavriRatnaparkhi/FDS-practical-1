# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir("C:/Users/Admin/Desktop/Savri/FDS/Datasets")
CarsData=pd.read_csv('Toyota.csv', index_col=0,na_values=['??','????'])
CarsData.size
# Out:
# 14360

# %%
CarsData.dropna(axis=0, inplace=True)
CarsData.size
# Out:
# 10960

# %%
CarsData.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
# 5  12950  32.0  61000.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 3    1165
# 4    1170
# 5    1170

# %%
sns.set(style="whitegrid")
sns.regplot(x=CarsData['Age'], y=CarsData['Price'])
plt.show()

# %%
sns.regplot(x=CarsData['Age'], y=CarsData['Price'],marker='*',fit_reg=False) # to remove the regression line 
plt.show()

# %%
sns.lmplot(x='Age', y='Price', hue='FuelType', data=CarsData, fit_reg=False)

# %%
sns.lmplot(x='Age', y='Price', hue='FuelType', data=CarsData, fit_reg=False, palette='Blues')

# %%
sns.distplot(CarsData['Age'], kde=False)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(CarsData['Age'], kde=False, bins=10)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(x=CarsData['FuelType'], palette='Set3')
plt.show()

# %%
sns.countplot(x=CarsData['FuelType'], hue=CarsData['Automatic'],palette='Set3')
plt.show()

# %%
pd.crosstab(index=CarsData['Automatic'], columns=CarsData['FuelType'])
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58

# %%
sns.boxplot(x=CarsData['FuelType'], y=CarsData['Price'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=CarsData['FuelType'], y=CarsData['Price'], hue=CarsData['Automatic'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
f,(ax_hist, ax_box)=plt.subplots(2, gridspec_kw={'height_ratios':[0.5,0.5]})
sns.histplot(CarsData['Age'], kde=False, ax=ax_hist)
sns.boxplot(x=CarsData['FuelType'], y=CarsData['Price'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sns.pairplot(CarsData, kind='scatter', hue='FuelType', diag_kws={'bw_method':0.5})

# %%
data=np.random.randint(1,100,size=(20,20))
print(data)
# Out:
# [[22 82 95 41 34 68 99 54  7 90  4 93 43 90 20 83 51 44 47 90]
#  [77 76 74 82 85  6 27 14 76 86 20 30 57 76 72 10  2 99 64 40]
#  [68 43 29  1 57 74  2 41  5 45 85 91 12 61 35 81 94 28 97 32]
#  [31 65 26 84 55  9 75 12 47 48 21 70 77 41 42 78 12  3 43 19]
#  [25 54 96 93 72 17 40 99 94 45 49 13 74 34 96 88 85 96 62 39]
#  [ 9 22 76 70 86 54 31 62 55  8 26 79 65 33 19 36 43  9 80 90]
#  [57  1 54 52 92 31 17 79 71 19 63 55 97 85 83 40 52 56 32 56]
#  [ 5 90 25 20 99 36 60 69 62 67 92 52 58 50 16 34 52 98 83 41]
#  [26 39  4 59 29 69 28 14 84  7 84 89 41 16 85 60 31 58 28 68]
#  [89 94 95 24 28 21 72 42 16  9 38 50  2 19 45 79  6 22 14 46]
#  [83 17 37 66 70 74 19 48 48 42 87 20 12 54 56 51 90 89 96 80]
#  [31 84 33 91 61 14 68 48 32 71 93 68 35 51  1 67 13 29 78 78]
#  [30 83 86 59 11  1 47 44 32  7 48 81 90 54 51 78 91 84 40  2]
#  [51 67 71 92 75 49 94 97 62 53  8 23 94 78 76 65 51 34 84 33]
#  [50 20 43 86 71 61 61 88 84 92 36 23  6 48 15 77 64 88 62 27]
# ...

# %%
hm=sns.heatmap(data=data, cmap='Blues',annot=True)
plt.show()

# %%
hm=sns.heatmap(data=data,vmin='30', vmax='70', cmap='BuPu')
plt.show()
